# %% [markdown]
# Numpy : #같은 폴더에 넣으니 된다. path지정을 안해줘 된다면,,,불러오는 곳이 정해져 있다는 것인가?
# xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)
#
# tensorflow에서도 파일 불러올 수 있네(마지막 cell 참조)
#
# *파일 위치바꿔서 다시 불러와보자

# %%
#slicing 기능이 있다
# Lab 4 Multi-variable linear regression
import tensorflow as tf
import numpy as np
tf.set_random_seed(777)  # for reproducibility

xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32) #같은 폴더에 넣으니 된다.
x_data = xy[:, 0:-1] #from a to b 에서 b는 포함하지 않는다.
y_data = xy[:, [-1]] #마지막 컬럼을 -1이라고 한다

# Make sure the shape and data are OK
print(x_data.shape, x_data, len(x_data)) #행 by 열, 데이터, 행의 수
print(y_data.shape, y_data)

# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight') # 3 by 1의 매트릭스를 만든다.
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)

# Ask my score
print("Your score will be ", sess.run(
    hypothesis, feed_dict={X: [[100, 70, 101]]}))

# new test score
print("Other scores will be ", sess.run(hypothesis,
                                        feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))

'''
Your score will be  [[ 181.73277283]]
Other scores will be  [[ 145.86265564]
 [ 187.23129272]]

'''
# Out:
# (25, 3) [[  73.   80.   75.]
#  [  93.   88.   93.]
#  [  89.   91.   90.]
#  [  96.   98.  100.]
#  [  73.   66.   70.]
#  [  53.   46.   55.]
#  [  69.   74.   77.]
#  [  47.   56.   60.]
#  [  87.   79.   90.]
#  [  79.   70.   88.]
#  [  69.   70.   73.]
#  [  70.   65.   74.]
#  [  93.   95.   91.]
#  [  79.   80.   73.]
#  [  70.   73.   78.]
#  [  93.   89.   96.]
#  [  78.   75.   68.]
#  [  81.   90.   93.]
#  [  88.   92.   86.]
#  [  78.   83.   77.]
#  [  82.   86.   90.]
#  [  86.   82.   89.]
#  [  78.   83.   85.]
#  [  76.   83.   71.]
#  [  96.   93.   95.]] 25
# (25, 1) [[ 152.]
#  [ 185.]
#  [ 180.]
#  [ 196.]
#  [ 142.]
#  [ 101.]
#  [ 149.]
#  [ 115.]
#  [ 175.]
#  [ 164.]
#  [ 141.]
#  [ 141.]
#  [ 184.]
#  [ 152.]
#  [ 148.]
#  [ 192.]
#  [ 147.]
#  [ 183.]
#  [ 177.]
#  [ 159.]
#  [ 177.]
#  [ 175.]
#  [ 175.]
#  [ 149.]
#  [ 192.]]
# 0 Cost:  181274.0
# Prediction:
#  [[-241.4982605 ]
#  [-300.36126709]
#  [-290.77703857]
#  [-316.65661621]
# ...

# %%
import tensorflow as tf
#tf.set_random_seed(777)  # for reproducibility

filename_queue = tf.train.string_input_producer(
    ['../data/data-01-test-score.csv'], shuffle=False, name='filename_queue')

reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# Default values, in case of empty columns. Also specifies the type of the
# decoded result.
record_defaults = [[0.], [0.], [0.], [0.]]  # 리스트형태의 메모리 각 마디마다 자료형태 정하기
xy = tf.decode_csv(value, record_defaults=record_defaults) #각 마디 저장소로부터 value값을 가져와 xy에 넣기

print(xy)
# collect batches of csv in
train_x_batch, train_y_batch = tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)
print(train_x_batch)
# Out:
# [<tf.Tensor 'DecodeCSV_3:0' shape=() dtype=float32>, <tf.Tensor 'DecodeCSV_3:1' shape=() dtype=float32>, <tf.Tensor 'DecodeCSV_3:2' shape=() dtype=float32>, <tf.Tensor 'DecodeCSV_3:3' shape=() dtype=float32>]
# Tensor("batch_3:0", shape=(10, 3), dtype=float32)

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Start populating the filename queue.
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)

for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    #batch가 10개씩 추출이면...for문 돌리는게 맞다
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_batch, Y: y_batch})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)

coord.request_stop()
coord.join(threads)

# Ask my score
print("Your score will be ",
      sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ",
      sess.run(hypothesis, feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# 0 Cost:  168151.0
# Prediction:
#  [[-227.18965149]
#  [-293.4274292 ]
#  [-278.17980957]
#  [-307.73580933]
#  [-225.02133179]
#  [-175.87539673]
#  [-231.91377258]
#  [-173.45648193]
#  [-284.90740967]
#  [-276.42721558]]
# 10 Cost:  224.762
# Prediction:
#  [[ 162.70359802]
#  [ 175.35903931]
#  [ 183.63154602]
#  [ 195.25517273]
#  [ 132.51142883]
#  [  87.80579376]
#  [ 144.60913086]
#  [ 105.69280243]
#  [ 153.29951477]
#  [ 129.57002258]]
# 20 Cost:  184.99
# Prediction:
#  [[ 165.2807312 ]
#  [ 178.55189514]
#  [ 186.72610474]
#  [ 198.65322876]
#  [ 134.94721985]
#  [  89.65576172]
#  [ 147.16740417]
#  [ 107.60709381]
#  [ 156.33969116]
#  [ 132.45614624]]
# 30 Cost:  183.1
# Prediction:
#  [[ 165.24440002]
#  [ 178.60269165]
#  [ 186.72520447]
#  [ 198.67990112]
#  [ 134.98661804]
#  [  89.73854065]
#  [ 147.20201111]
#  [ 107.65041351]
#  [ 156.44287109]
#  [ 132.62132263]]
# 40 Cost:  181.429
# Prediction:
#  [[ 165.19067383]
#  [ 178.63214111]
#  [ 186.70352173]
# ...
